# %%
# steaming
import nltk
import pandas as pd
import re
from nltk import word_tokenize
import string 
import pickle
from nltk.stem import StemmerI, RegexpStemmer, LancasterStemmer, ISRIStemmer, PorterStemmer, SnowballStemmer, RSLPStemmer

# # read tokens
# infile = open('filtered_tweets_test.pickle','rb')
# tweets = pickle.load(infile)
# infile.close()

# #stemmer = WordNetLemmatizer()
# #stemmer = LancasterStemmer()
# stemmer = SnowballStemmer('english')
# #stemmer = PorterStemmer()

# # tokenize
# tokens=[word_tokenize(s) for s in tweets]

# # steamming
# stems=[]
# for tweet in tokens:
#     tmp=[]
#     for w in tweet:
#         tmp.append(stemmer.stem(w))
#     stems.append(tmp)

# # detokenize
# stemmed_tweets=[]
# for tweet in stems:
#     if tweet:
#         tmp=tweet[0]
#         for word in tweet[1:]:
#             tmp=tmp+' '+word
#     else:
#         tmp=''
#     stemmed_tweets.append(tmp)
    
# # save stemmed_tweets
# outfile=open('stemmed_tweets_test.pickle','wb')
# pickle.dump(stemmed_tweets,outfile)
# outfile.close()
    
# read stemmed_tweets
infile = open('stemmed_tweets_test.pickle','rb')
stemmed_tweets = pickle.load(infile)
infile.close()

print(stemmed_tweets)
# Out:
# ['arianagrand ari ariana grand full singer actress', 'ariana grand kii fm truli cd listen parti burbank arianagrand', 'ariana grand white hous easter egg roll washington arianagrand', 'cd music ariana grand sweet like candi oz ml seal box authen new', 'side side sidetosid arianagrand music comunidadgay lgbt lotb', 'hairspray live preview maci thanksgiv day parad arianagrand televisionnbc', 'lindsaylohan feel thank blast arianagrand wear toomuch', 'hate love song dammit arianagrand', 'ariana grand right ft big sean arianagrand', 'one would prefer listen whole day could never choos arianagrand intoyou sidetosid song poll', 'booti babi ariarianagrand princessari bootybabi dangerouswomantour dangerouswoman', 'lindsaylohan back ketter holiday appear throw shade arianagrand lilo', 'idol littlemix justinbieb arianagrand', 'ariana grand sim simsdomin arianagrand', 'music arianagrandeth remixjapan cd e bestsel hit', 'beauti arianagrandechristma chilljapan cd bonus track c deal topsel', 'popular song ahh said im put stori popular song taylor arianagrand justin music', 'ariana grand privat event coach japan august arianagrand', 'beauti arianagrandeth remixjapan cd e deal topsel', 'one last time arianagrand', 'newarriv pentatonix christmasalbum arianagrand frankzappa leonardcohen hallelujah bobdylan', 'much love woman ughh arianagrand', 'ariana lip mac ariana arianagrand', 'ariana grand nyc pride danc pier arianagrand', 'thank god friday thanksgiv arianagrand arian', 'music arianagrand pm1600ariana grand babi', 'new big fan arianagrand nickiminaj barbi barbz arian', 'soro brainwash enslav blacklivesmatt protest fool naiv want social studi venezuela compar moron', 'obama latest blacklivesmatt recruit videowelcom modesto mall', 'iggi therevolut club mad trump call chicago sanctuari citywhatblacklivesmatt maga', 'blacklivesmatt potus hillaryclinton call get chant disgrac', 'babi also dont even understand blacklivesmatt actual mean repres laugh loud your dismiss kid', 'lake counti black live matter host thanksgiv food distribut chicago tribun', 'blacklivesmatt protest hit black driver via oh god funni', 'there enough hair track death blacklivesmatt remind cool art seattl afam museum', 'blacklivesmatt protest black violenc kill near black', 'news must unit oppress indigenousright blacklivesmatt j disruptj', 'donald trump great mani reason label blacklivesmatt hate group bye bye obama', 'latest hasem ben sober daili mulch blackfriday blacklivesmatt', 'elector colleg must reject trump rejecttrump notmypresid takingbackdemocraci blacklivesmatt nevertrump', 'yeah polic action blacklivesmatt that problem young black kid gun drug', 'latest humanitarian daili blacklivesmatt notmypresid', 'anarchist bottom feeder worst societi like domest terrorist blacklivesmatt', 'blacklivesmatterblock access white own storesin nazi boycot jewish own storesdidnt know kaffir nazi', 'leftist smurf defac landmark anti trump lie dayafterthanksgiv alivesmatt maga', 'love chicago cop gun blacklivesmatt thug chicago laugh loud naacp bluelivesmatt blacktwitt', 'simpli mean english provid support blacklivesmatt set h', 'rest peac jamesmean im pray famili blacklivesmatt', 'keep blacklivesmatt youll ensur victori maga', 'constitut right film polic blacklivesmatt stoprac stopfasc notonmywatch', 'vid hide valuabl insid hollow decor candl tpp blacklivesmatt atr', 'give listen raw project one realest blacklivesmatt unapologeticallyblack', 'lead firepanatleo chant justicenow blackfriday march ericgarn', 'thank retard blacklivesmatt blacktwitt', 'relev blacklivesmatt white man cop', 'therealblackfriday start fill get blackmad merchandis blackfriday blexit', 'faith leader shutdown lord taylor ericgarn deborahdann', 'two year ago last night polic ferguson missouri tear gass attack three safe zone still rememberblacklivesmatt', 'cours relev blacklivesmatt black life brutal taken away', 'year later fianc e nypd shoot victim sean bell speak blacklivesmatt', 'smdh countri care black frida ...

# %%
# from nltk.corpus import wordnet

# # Lemmatize with POS Tag
# def get_wordnet_pos(word):
#     """Map POS tag to first character lemmatize() accepts"""
#     tag = nltk.pos_tag([word])[0][1][0].upper()
#     tag_dict = {"J": wordnet.ADJ,
#                 "N": wordnet.NOUN,
#                 "V": wordnet.VERB,
#                 "R": wordnet.ADV}
#     return tag_dict.get(tag, wordnet.NOUN)

# from nltk.stem import  WordNetLemmatizer
# lemmatizer = WordNetLemmatizer()

# # read tokens
# infile = open('filtered_tweets_test.pickle','rb')
# tweets = pickle.load(infile)
# infile.close()

# # tokenize
# tokens=[word_tokenize(s) for s in tweets]

# # lemmatize all words in [[],[],...] format
# lemmatized=[]
# for tweet in tokens:
#     tmp=[]
#     for w in tweet:
#         tmp.append(lemmatizer.lemmatize(w, get_wordnet_pos(w)))
#     lemmatized.append(tmp)
    
# # detokenize
# lemmatized_tweets=[]
# for tweet in lemmatized:
#     if tweet:
#         tmp=tweet[0]
#         for word in tweet[1:]:
#             tmp=tmp+' '+word
#     else:
#         tmp=''
#     lemmatized_tweets.append(tmp)
    
# # saving lemmatized_tweets 
# outfile=open('lemmatized_tweets_test.pickle','wb')
# pickle.dump(lemmatized_tweets,outfile)
# outfile.close()

# read lemmatized_tweets 
infile = open('lemmatized_tweets_test.pickle','rb')
lemmatized_tweets = pickle.load(infile)
infile.close()
    
print(lemmatized_tweets)
# Out:
