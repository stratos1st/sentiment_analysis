# %%
# steaming
import nltk
import pandas as pd
import re
from nltk import word_tokenize
import string 
import pickle
from nltk.stem import StemmerI, RegexpStemmer, LancasterStemmer, ISRIStemmer, PorterStemmer, SnowballStemmer, RSLPStemmer

# # read tokens
# infile = open('filtered_tweets_train.pickle','rb')
# tweets = pickle.load(infile)
# infile.close()

# #stemmer = WordNetLemmatizer()
# #stemmer = LancasterStemmer()
# stemmer = SnowballStemmer('english')
# #stemmer = PorterStemmer()

# # tokenize
# tokens=[word_tokenize(s) for s in tweets]

# # steamming
# stems=[]
# for tweet in tokens:
#     tmp=[]
#     for w in tweet:
#         tmp.append(stemmer.stem(w))
#     stems.append(tmp)

# # detokenize
# stemmed_tweets=[]
# for tweet in stems:
#     if tweet:
#         tmp=tweet[0]
#         for word in tweet[1:]:
#             tmp=tmp+' '+word
#     else:
#         tmp=''
#     stemmed_tweets.append(tmp)
    
# # save stemmed_tweets
# outfile=open('stemmed_tweets_train.pickle','wb')
# pickle.dump(stemmed_tweets,outfile)
# outfile.close()
    
# read stemmed_tweets
infile = open('stemmed_tweets_train.pickle','rb')
stemmed_tweets = pickle.load(infile)
infile.close()

print(stemmed_tweets)
# Out:
# ['gas hous hit im go chapel hill sat', 'theo walcott still shit watch rafa johnni deal saturday', 'im gsp fan hate nick diaz cant wait februari', 'iranian general say israel iron dome cant deal missil keep talk like may end find', 'tehran mon amour obama tri establish tie mullah via com barack obama vote mitt romney', 'sat whole movi harri ron christma ohlawd', 'j davlar 11th main rival team poland hope make success end tough week train tomorrow', 'talk act sat decid want go colleg appli colleg everyth colleg stress', 'happi valentin day trend 14th februari 12th june smh', 'may superbowl dalla dalla aint win superbowl quarterback owner', 'im bring monster load candi tomorrow hope doesnt get squich', 'appl softwar retail chief overhaul san francisco appl inc ceo tim cook monday replac head', 'otti watch sridevi comeback rememb 90s sun morn nta', 'one best 8th grader kori excit touchdown today victor cruzlol', 'livewir nadal confirm mexican open februari rafael nadal set play livewireathlet', 'didnt want pop yep chapel hill next wednesday come shes great ill tell ask', 'hm novemb odd releas date true becom big enough mayb could sing grammi', 'iran us delist mko global terrorist list line iran campaign tehran oct irna secretari', 'serg amaz like hes actual god lanki sex god saw kasabian noel togeth august amaz', 'larri bird rank 4th alltim includ lebron kobe sayin', 'good morn becki thursday go fantast', 'expect lightmoder rain e visaya cebu bohol samar leyt chanc rain tonight expect fair weather tomorrow', 'one ticket left game tomorrow dont miss rematch nfc championship game ny giant hit', 'afc away fan saturday stuff said chant bollock ball turn back', 'saturday night consist watch grey puppi parent throw rager whaa liamneesonisbosstho', 'hard find day went store castl cover issu none search tomorrow', 'game nlcs rematch nfc championship game tomorrow sfs gon na cuhraz', 'jame hall live indianapoli dec8th christ church apostol tix 10adv', 'heat game may cost alot moreand plus would rather see austin river play', 'never start work dream goal tomorrowtomorrow never comesif mean anyth act getafterit', 'vick flacco need upgrad vick may get bench jen back soon thought win', 'key largo fl yay ur neighbor lisa sip n hop away alway watch rhom thur', 'look like andi android may littl much fun yesterday', 'oh nice tis tempt go lake nikon hm may', 'black friday huge save aerial view citi pari las vega las vega strip las vega', 'yes know indio vs cv tomorrow bell game enough', 'delpham jenell lies1st said alon hospnow shes say weird keiffer', 'lmfao big ass get nerv go class tomorrow', 'im go hong kong time mama nov want see live', 'happi 20th mr presid nick j forev chain', 'dream high suck compar 1st one', 'moham morsi egypt muslim brotherhood presid instruct suprem council arm forc thursday', 'cmon avila got tag guy look like kid bill murray research royal tenenbaum tiger', 'think boro beat swansea im sure decemberjanuari implod', 'first grammi award held may domenico modugno beat frank sinatra peggi lee record yearwith volar', 'happi birthday vow 3rd anniversari', 'studi day tomorrow im go friend oh god jennett im gon na look', 'good morn thursday life fragil guarante tomorrow give everyth youv got tim cook job', 'twitit mcfli come back argentina time want come mar del plata', 'anyth wonder aspect btwn sunmoon fair rise also venus sagyea laugh loud thank', 'teacher call givng us candywasnt even good stuff might go walmart cvs tomorrow', 'bring kendrick lamar 6th decemb get ticket', 'may android phone time get back school', 'andr wigan warn coy offici site wigan might current occupi 15th place premier leagu', 'tryst tonight best industrylocalthursday parti las vega', 'rain didnt care said someday soon sun gon na shine right love mine valentin', 'royal rumbl tomorrow night hous assembl crew gettin real time haahaha', 'strang enough im go see noel gallagh concert tomorrow night alldayb1tch', 'professor pass candi say small amount may vale ...

# %%
# from nltk.corpus import wordnet

# # Lemmatize with POS Tag
# def get_wordnet_pos(word):
#     """Map POS tag to first character lemmatize() accepts"""
#     tag = nltk.pos_tag([word])[0][1][0].upper()
#     tag_dict = {"J": wordnet.ADJ,
#                 "N": wordnet.NOUN,
#                 "V": wordnet.VERB,
#                 "R": wordnet.ADV}
#     return tag_dict.get(tag, wordnet.NOUN)

# from nltk.stem import  WordNetLemmatizer
# lemmatizer = WordNetLemmatizer()

# # read tokens
# infile = open('filtered_tweets_train.pickle','rb')
# tweets = pickle.load(infile)
# infile.close()

# # tokenize
# tokens=[word_tokenize(s) for s in tweets]

# # lemmatize all words in [[],[],...] format
# lemmatized=[]
# for tweet in tokens:
#     tmp=[]
#     for w in tweet:
#         tmp.append(lemmatizer.lemmatize(w, get_wordnet_pos(w)))
#     lemmatized.append(tmp)
    
# # detokenize
# lemmatized_tweets=[]
# for tweet in lemmatized:
#     if tweet:
#         tmp=tweet[0]
#         for word in tweet[1:]:
#             tmp=tmp+' '+word
#     else:
#         tmp=''
#     lemmatized_tweets.append(tmp)
    
# # saving lemmatized_tweets 
# outfile=open('lemmatized_tweets_train.pickle','wb')
# pickle.dump(lemmatized_tweets,outfile)
# outfile.close()

# read lemmatized_tweets 
infile = open('lemmatized_tweets_train.pickle','rb')
lemmatized_tweets = pickle.load(infile)
infile.close()
    
print(lemmatized_tweets)
# Out:
