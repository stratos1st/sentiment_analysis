# %%
import nltk
import pandas as pd
import re
from nltk import word_tokenize
import string 
from nltk.corpus import stopwords
import pickle
import csv

# # read data
# Location = r'/home/stratos/Desktop/ted_Project/twitter_data/train2017.tsv'
# df = pd.read_csv(Location, error_bad_lines=False,
#                  names=['no1','no2','cent','tweet'],
#                 sep='\t')

# def remove_duck(s):
#     return re.sub(r'@[A-Za-z0-9]+',' ',s)

# def remove_links(s):
#     return re.sub('https?://[A-Za-z0-9./]+',' ',s)

# def remove_numbers(s):
#     return re.sub('(?:[0-9]+\s+|[0-9]+$)',' ',s)

# def remove_consecutive(s):
#     return re.sub(r"(\w)\1{2,}",r'\1',s)

# def remove_whitespace(s):
#     return re.sub('\s+', ' ', s).strip()

# def remove_unicode(s):
#     return re.sub(r'\\u\s', ' ', s)

# def remove_punctuation(s):
#     exclude = set(string.punctuation)
#     s = ''.join(ch for ch in s if ch not in exclude)
#     return s

# def remove_stopwords(s):
#     stop_words = set(stopwords.words('english'))   
#     a=[w for w in word_tokenize(s) if not w in stop_words] 
#     tmp=''
#     for word in a:
#         tmp=tmp+' '+word
#     return tmp

# # Code From: https://medium.com/nerd-stuff/python-script-to-turn-text-message-abbreviations-into-actual-phrases-d5db6f489222
# def remove_slang(user_string):
#     user_string = user_string.split(" ")
#     j = 0
#     for _str in user_string:
#         # File path which consists of Abbreviations.
#         fileName = "/home/stratos/Desktop/ted_Project/lexica/slang.txt"

#         # File Access mode [Read Mode]
#         with open(fileName, "r") as myCSVfile:
#             # Reading file as CSV with delimiter as "=", so that abbreviation are stored in row[0] and phrases in row[1]
#             dataFromFile = csv.reader(myCSVfile, delimiter="=")
#             # Removing Special Characters.
#             _str = re.sub('[^a-zA-Z0-9]+', '', _str)
#             for row in dataFromFile:
#                 # Check if selected word matches short forms[LHS] in text file.
#                 if _str.upper() == row[0]:
#                     # If match found replace it with its appropriate phrase in text file.
#                     user_string[j] = row[1]
#             myCSVfile.close()
#         j = j + 1
#     return ' '.join(user_string)


# tokens=[]
# cent=[]
# for index, row in df.iterrows():
#     s=row['tweet']
# #     s=remove_unicode(s)
#     s=remove_duck(s)
#     s=remove_links(s)
#     s=remove_slang(s)
#     s=remove_punctuation(s)
#     s=s.lower()
#     s=remove_stopwords(s)
#     s=remove_numbers(s)
#     s=remove_consecutive(s)
#     s=remove_whitespace(s)
#     tokens.append(s)
#     cent.append(row['cent'])

# # save tokens
# outfile=open('filtered_tweets_train.pickle','wb')
# pickle.dump(tokens,outfile)
# outfile.close()

# # save cent
# outfile=open('cent_train.pickle','wb')
# pickle.dump(cent,outfile)
# outfile.close()

# read tokens
infile = open('filtered_tweets_train.pickle','rb')
tokens = pickle.load(infile)
infile.close()

# read cent
infile = open('cent_train.pickle','rb')
cent = pickle.load(infile)
infile.close()

print(tokens,cent)
# Out:
# ['gas house hit im going chapel hill sat', 'theo walcott still shit watch rafa johnny deal saturday', 'im gsp fan hate nick diaz cant wait february', 'iranian general says israels iron dome cant deal missiles keep talking like may end finding', 'tehran mon amour obama tried establish ties mullahs via com barack obama vote mitt romney', 'sat whole movie harry ron christmas ohlawd', 'j davlar 11th main rivals team poland hopefully make successful end tough week training tomorrow', 'talking acts sats deciding want go college applying colleges everything college stresses', 'happy valentines day trending 14th february 12th june smh', 'may superbowl dallas dallas aint winning superbowl quarterback owner', 'im bringing monster load candy tomorrow hope doesnt get squiched', 'apple software retail chiefs overhaul san francisco apple inc ceo tim cook monday replaced heads', 'otti watched sridevis comeback remember 90s sun mornings nta', 'one best 8th graders kory excited touchdown today victor cruzlol', 'livewire nadal confirmed mexican open february rafael nadal set play livewireathletics', 'didnt want pop yep chapel hill next wednesday come shes great ill tell asked', 'hm november odd release date true becomes big enough maybe could sing grammys', 'iran us delisting mko global terrorists list line iran campaign tehran oct irna secretary', 'serge amazing like hes actually god lanky sex god saw kasabian noel together august amazing', 'larry bird ranked 4th alltime including lebron kobe sayin', 'good morning becky thursday going fantastic', 'expect lightmoderate rains e visayas cebu bohol samar leyte chance rains tonight expect fair weather tomorrow', 'one ticket left game tomorrow dont miss rematch nfc championship game ny giants hit', 'afc away fans saturday stuff said chant bollocks ball turn back', 'saturday night consisted watching grey puppy parents throw rager whaa liamneesonisbosstho', 'hard find days went stores castle cover issue none search tomorrow', 'game nlcs rematch nfc championship game tomorrow sfs gon na cuhraze', 'james hall live indianapolis dec8th christ church apostolic tixs 10adv', 'heat game may cost alot moreand plus would rather see austin rivers play', 'never start working dreams goals tomorrowtomorrow never comesif means anything act getafterit', 'vick flacco needed upgrade vick may get benched jennings back soon thought win', 'key largo fl yay ur neighbor lisa sip n hop away always watching rhom thurs', 'looks like andy android may little much fun yesterday', 'oh nice tis tempting go lakes nikon hm may', 'black friday huge saving aerial view city paris las vegas las vegas strip las vegas', 'yes know indio vs cv tomorrow bell game enough', 'delpham jenelle lies1st said alone hospnow shes saying weird keiffers', 'lmfao big ass get nerves going class tomorrow', 'im going hong kong time mama nov want see live', 'happy 20th mr president nick j forever chain', 'dream high sucks compared 1st one', 'mohamed morsi egypts muslim brotherhood president instructed supreme council armed forces thursday', 'cmon avila got tagged guy looks like kid bill murray researching royal tenenbaums tigers', 'think boro beat swansea im sure decemberjanuary implode', 'first grammy awards held may domenico modugno beat frank sinatra peggy lee record yearwith volare', 'happy birthday vow 3rd anniversary', 'studied day tomorrow im going friends oh god jennette im gon na look', 'good morning thursday life fragile guaranteed tomorrow give everything youve got tim cook jobs', 'twitition mcfly come back argentina time want come mar del plata', 'anything wondered aspects btwn sunmoon faired rising also venus sagyea laughing loud thank', 'teachers call givng us candywasnt even good stuff might go walmart cvs tomorrow', 'bringing kendrick lamar 6th december get tickets', 'may android phone time get back school', 'andres wigan warning coys official site wigan might currently occupy 15th place premier league', 'tryst tonight best industrylocalthursd ...
